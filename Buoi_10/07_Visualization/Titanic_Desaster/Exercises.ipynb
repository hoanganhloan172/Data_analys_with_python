# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/titanic_train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
url = "https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/titanic_train.csv"

titanic = pd.read_csv(url)

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic.set_index('PassengerId', inplace=True)

print(titanic.head())
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
import matplotlib.pyplot as plt
# Count the number of males and females
gender_counts = titanic['Sex'].value_counts()

# Plot pie chart
plt.figure(figsize=(8, 6))
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'salmon'])
plt.title('Male/Female Proportion in Titanic Dataset')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
import matplotlib.pyplot as plt

# Create scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(titanic[titanic['Sex'] == 'male']['Age'], titanic[titanic['Sex'] == 'male']['Fare'], color='skyblue', label='Male', alpha=0.5)
plt.scatter(titanic[titanic['Sex'] == 'female']['Age'], titanic[titanic['Sex'] == 'female']['Fare'], color='salmon', label='Female', alpha=0.5)
plt.title('Scatter Plot of Fare vs Age, Colored by Gender')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
survived_count = titanic['Survived'].sum()

print("Number of people who survived:", survived_count)
# Out:
# Number of people who survived: 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
import matplotlib.pyplot as plt

# Create histogram of the 'Fare' column
plt.figure(figsize=(10, 6))
plt.hist(titanic['Fare'], bins=20, color='skyblue', edgecolor='black')
plt.title('Histogram of Fare Paid')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.
